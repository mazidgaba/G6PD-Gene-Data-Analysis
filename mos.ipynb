# %%
import pandas as pd


df = pd.read_excel('mos.xlsx')

# Print the DataFrame to see the data
print(df)
# Out:
#     donor_id   donor_name donor_age donor_color  structure_id  \
# 0      12296   H376.VI.50     4 mos      80FF80         10278
# 1      12296   H376.VI.50     4 mos      80FF80         10243
# 2      12296   H376.VI.50     4 mos      80FF80         10252
# 3      12296   H376.VI.50     4 mos      80FF80         10269
# 4      12296   H376.VI.50     4 mos      80FF80         10294
# 5      12296   H376.VI.50     4 mos      80FF80         10361
# 6      12296   H376.VI.50     4 mos      80FF80         10333
# 7      12296   H376.VI.50     4 mos      80FF80         10398
# 8      12296   H376.VI.50     4 mos      80FF80         10657
# 9      12889   H376.VI.51     4 mos      76EB76         10173
# 10     12889   H376.VI.51     4 mos      76EB76         10185
# 11     12889   H376.VI.51     4 mos      76EB76         10194
# 12     12889   H376.VI.51     4 mos      76EB76         10163
# 13     12889   H376.VI.51     4 mos      76EB76         10236
# 14     12889   H376.VI.51     4 mos      76EB76         10243
# 15     12889   H376.VI.51     4 mos      76EB76         10252
# 16     12889   H376.VI.51     4 mos      76EB76         10361
# 17     12890   H376.VI.52     4 mos      6CD66C         10173
# 18     12890   H376.VI.52     4 mos      6CD66C         10185
# 19     12890   H376.VI.52     4 mos      6CD66C         10278
# 20     12890   H376.VI.52     4 mos      6CD66C         10194
# 21     12890   H376.VI.52     4 mos      6CD66C         10163
# 22     12890   H376.VI.52     4 mos      6CD66C         10209
# 23     12890   H376.VI.52     4 mos      6CD66C         10225
# 24     12890   H376.VI.52     4 mos      6CD66C         10236
# 25     12890   H376.VI.52     4 mos      6CD66C         10243
# 26     12890   H376.VI.52     4 mos      6CD66C         10252
# 27     12890   H376.VI.52     4 mos      6CD66C         10269
# 28     12890   H376.VI.52     4 mos      6CD66C         10294
# 29     12890   H376.VI.52     4 mos      6CD66C         10361
# 30     12890   H376.VI.52     4 mos      6CD66C         10333
# 31     12890   H376.VI.52     4 mos      6CD66C         10398
# 32     12890   H376.VI.52     4 mos      6CD66C         10657
# 33     12977  H376.VII.51    10 mos      B0EB3B         10173
# 34     12977  H376.VII.51    10 mos      B0EB3B         10278
# 35     12977  H376.VII.51    10 mos      B0EB3B         10194
# 36     12977  H376.VII.51    10 mos      B0EB3B         10209
# 37     12977  H376.VII.51    10 mos      B0EB3B         10225
# 38     12977  H376.VII.51    10 mos      B0EB3B         10243
# 39     12977  H376.VII.51    10 mos      B0EB3B         10252
# 40     12977  H376.VII.51    10 mos      B0EB3B         10269
# 41     12977  H376.VII.51    10 mos      B0EB3B         10398
# 42     12977  H376.VII.51    10 mos      B0EB3B         10657
#
#                                        structure_name structure_abbreviation  \
# 0   anterior (rostral) cingulate (medial prefronta...                    MFC
# 1   posterior (caudal) superior temporal cortex (a...                    STC
# 2   inferolateral temporal cortex (area TEv, area 20)                    ITC
# 3   primary visual cortex (striate cortex, area V1...                    V1C
# 4                 hippocampus (hippocampal formation)                    HIP
# 5                                  amygdaloid complex                    AMY
# 6                                            striatum                    STR
# 7                     mediodorsal nucleus of thalamus                     MD
# 8                                   cerebellar cortex                    CBC
# 9                      dorsolateral prefrontal cortex                    DFC
# 10                    ventrolateral prefrontal cortex                    VFC
# 11                             orbital frontal cortex                    OFC
# 12             primary motor cortex (area M1, area 4)                    M1C
# 13                     primary auditory cortex (core)                    A1C
# 14  posterior (caudal) superior temporal cortex (a...                    STC
# 15  inferolateral temporal cortex (area TEv, area 20)                    ITC
# 16                                 amygdaloid complex                    AMY
# 17                     dorsolateral prefrontal cortex                    DFC
# 18                    ventrolateral prefrontal cortex                    VFC
# 19  anterior (rostral) cingulate (medial prefronta...                    MFC
# 20                             orbital frontal cortex                    OFC
# 21             primary motor cortex (area M1, area 4)                    M1C
# 22  primary somatosensory cortex (area S1, areas 3...                    S1C
# 23          posteroventral (inferior) parietal cortex                    IPC
# 24                     primary auditory cortex (core)                    A1C
# 25  posterior (caudal) superior temporal cortex (a...                    STC
# 26  inferolateral temporal cortex (area TEv, area 20)                    ITC
# 27  primary visual cortex (striate cortex, area V1...                    V1C
# 28                hippocampus (hippocampal formation)                    HIP
# 29                                 amygdaloid complex                    AMY
# 30                                           striatum                    STR
# 31                    mediodorsal nucleus of thalamus                     MD
# 32                                  cerebellar cortex                    CBC
# 33                     dorsolateral prefrontal cortex                    DFC
# 34  anterior (rostral) cingulate (medial prefronta...                    MFC
# 35                             orbital frontal cortex                    OFC
# 36  primary somatosensory cortex (area S1, areas 3...                    S1C
# 37          posteroventral (inferior) parietal cortex                    IPC
# 38  posterior (caudal) superior temporal cortex (a...                    STC
# 39  inferolateral temporal cortex (area TEv, area 20)                    ITC
# 40  primary visual cortex (striate cortex, area V1...                    V1C
# 41                    mediodorsal nucleus of thalamus                     MD
# 42                                  cerebellar cortex                    CBC
#
#    structure_color  top_level_structure_id      top_level_structure_name  \
# 0           E26880                   10153                  neural plate
# 1           D670A0                   10153                  neural plate
# 2           D55C92                   10153                  neural plate
# 3           C13331                   10153                  neural plate
# 4           BFB5D5                   10292                    allocortex
# 5           C9E2B1                   10153                  neural plate
# 6           C1CEA7                   10332  basal nuclei (basal ganglia)
# 7           B067A9                   10390                      thalamus
# 8           89ADDB                   10153                  neural plate
# 9           D4B235                   10153                  neural plate
# 10          C2A335                   10153                  neural plate
# 11          E2D4A7                   10153                  neural plate
# 12          EDCF37                   10153                  neural plate
# 13          D670A0                   10153                  neural plate
# 14          D670A0                   10153                  neural plate
# 15          D55C92                   10153                  neural plate
# 16          C9E2B1                   10153                  neural plate
# 17          D4B235                   10153                  neural plate
# 18          C2A335                   10153                  neural plate
# 19          E26880                   10153                  neural plate
# 20          E2D4A7                   10153                  neural plate
# 21          EDCF37                   10153                  neural plate
# 22          EC813B                   10153                  neural plate
# 23          D38E32                   10153                  neural plate
# 24          D670A0                   10153                  neural plate
# 25          D670A0                   10153                  neural plate
# 26          D55C92                   10153                  neural plate
# 27          C13331                   10153                  neural plate
# 28          BFB5D5                   10292                    allocortex
# 29          C9E2B1                   10153                  neural plate
# 30          C1CEA7                   10332  basal nuclei (basal ganglia)
# 31          B067A9                   10390                      thalamus
# 32          89ADDB                   10153                  neural plate
# 33          D4B235                   10153                  neural plate
# 34          E26880                   10153                  neural plate
# 35          E2D4A7                   10153                  neural plate
# 36          EC813B                   10153                  neural plate
# 37          D38E32                   10153                  neural plate
# 38          D670A0                   10153                  neural plate
# 39          D55C92                   10153                  neural plate
# 40          C13331                   10153                  neural plate
# 41          B067A9                   10390                      thalamus
# 42          89ADDB                   10153                  neural plate
#
#    top_level_structure_abbreviation top_level_structure_color
# 0                                NP                    D7D8D8
# 1                                NP                    D7D8D8
# 2                                NP                    D7D8D8
# 3                                NP                    D7D8D8
# 4                               ACx                    D1CEE2
# 5                                NP                    D7D8D8
# 6                                BN                    E2EACA
# 7                               THM                    E4CCE3
# 8                                NP                    D7D8D8
# 9                                NP                    D7D8D8
# 10                               NP                    D7D8D8
# 11                               NP                    D7D8D8
# 12                               NP                    D7D8D8
# 13                               NP                    D7D8D8
# 14                               NP                    D7D8D8
# 15                               NP                    D7D8D8
# 16                               NP                    D7D8D8
# 17                               NP                    D7D8D8
# 18                               NP                    D7D8D8
# 19                               NP                    D7D8D8
# 20                               NP                    D7D8D8
# 21                               NP                    D7D8D8
# 22                               NP                    D7D8D8
# 23                               NP                    D7D8D8
# 24                               NP                    D7D8D8
# 25                               NP                    D7D8D8
# 26                               NP                    D7D8D8
# 27                               NP                    D7D8D8
# 28                              ACx                    D1CEE2
# 29                               NP                    D7D8D8
# 30                               BN                    E2EACA
# 31                              THM                    E4CCE3
# 32                               NP                    D7D8D8
# 33                               NP                    D7D8D8
# 34                               NP                    D7D8D8
# 35                               NP                    D7D8D8
# 36                               NP                    D7D8D8
# 37                               NP                    D7D8D8
# 38                               NP                    D7D8D8
# 39                               NP                    D7D8D8
# 40                               NP                    D7D8D8
# 41                              THM                    E4CCE3
# 42                               NP                    D7D8D8

# %%
print(df.to_string())
# Out:
#     donor_id   donor_name donor_age donor_color  structure_id                                           structure_name structure_abbreviation structure_color  top_level_structure_id      top_level_structure_name top_level_structure_abbreviation top_level_structure_color
# 0      12296   H376.VI.50     4 mos      80FF80         10278  anterior (rostral) cingulate (medial prefrontal) cortex                    MFC          E26880                   10153                  neural plate                               NP                    D7D8D8
# 1      12296   H376.VI.50     4 mos      80FF80         10243   posterior (caudal) superior temporal cortex (area 22c)                    STC          D670A0                   10153                  neural plate                               NP                    D7D8D8
# 2      12296   H376.VI.50     4 mos      80FF80         10252        inferolateral temporal cortex (area TEv, area 20)                    ITC          D55C92                   10153                  neural plate                               NP                    D7D8D8
# 3      12296   H376.VI.50     4 mos      80FF80         10269       primary visual cortex (striate cortex, area V1/17)                    V1C          C13331                   10153                  neural plate                               NP                    D7D8D8
# 4      12296   H376.VI.50     4 mos      80FF80         10294                      hippocampus (hippocampal formation)                    HIP          BFB5D5                   10292                    allocortex                              ACx                    D1CEE2
# 5      12296   H376.VI.50     4 mos      80FF80         10361                                       amygdaloid complex                    AMY          C9E2B1                   10153                  neural plate                               NP                    D7D8D8
# 6      12296   H376.VI.50     4 mos      80FF80         10333                                                 striatum                    STR          C1CEA7                   10332  basal nuclei (basal ganglia)                               BN                    E2EACA
# 7      12296   H376.VI.50     4 mos      80FF80         10398                          mediodorsal nucleus of thalamus                     MD          B067A9                   10390                      thalamus                              THM                    E4CCE3
# 8      12296   H376.VI.50     4 mos      80FF80         10657                                        cerebellar cortex                    CBC          89ADDB                   10153                  neural plate                               NP                    D7D8D8
# 9      12889   H376.VI.51     4 mos      76EB76         10173                           dorsolateral prefrontal cortex                    DFC          D4B235                   10153                  neural plate                               NP                    D7D8D8
# 10     12889   H376.VI.51     4 mos      76EB76         10185                          ventrolateral prefrontal cortex                    VFC          C2A335                   10153                  neural plate                               NP                    D7D8D8
# 11     12889   H376.VI.51     4 mos      76EB76         10194                                   orbital frontal cortex                    OFC          E2D4A7                   10153                  neural plate                               NP                    D7D8D8
# 12     12889   H376.VI.51     4 mos      76EB76         10163                   primary motor cortex (area M1, area 4)                    M1C          EDCF37                   10153                  neural plate                               NP                    D7D8D8
# 13     12889   H376.VI.51     4 mos      76EB76         10236                           primary auditory cortex (core)                    A1C          D670A0                   10153                  neural plate                               NP                    D7D8D8
# 14     12889   H376.VI.51     4 mos      76EB76         10243   posterior (caudal) superior temporal cortex (area 22c)                    STC          D670A0                   10153                  neural plate                               NP                    D7D8D8
# 15     12889   H376.VI.51     4 mos      76EB76         10252        inferolateral temporal cortex (area TEv, area 20)                    ITC          D55C92                   10153                  neural plate                               NP                    D7D8D8
# 16     12889   H376.VI.51     4 mos      76EB76         10361                                       amygdaloid complex                    AMY          C9E2B1                   10153                  neural plate                               NP                    D7D8D8
# 17     12890   H376.VI.52     4 mos      6CD66C         10173                           dorsolateral prefrontal cortex                    DFC          D4B235                   10153                  neural plate                               NP                    D7D8D8
# 18     12890   H376.VI.52     4 mos      6CD66C         10185                          ventrolateral prefrontal cortex                    VFC          C2A335                   10153                  neural plate                               NP                    D7D8D8
# 19     12890   H376.VI.52     4 mos      6CD66C         10278  anterior (rostral) cingulate (medial prefrontal) cortex                    MFC          E26880                   10153                  neural plate                               NP                    D7D8D8
# 20     12890   H376.VI.52     4 mos      6CD66C         10194                                   orbital frontal cortex                    OFC          E2D4A7                   10153                  neural plate                               NP                    D7D8D8
# 21     12890   H376.VI.52     4 mos      6CD66C         10163                   primary motor cortex (area M1, area 4)                    M1C          EDCF37                   10153                  neural plate                               NP                    D7D8D8
# 22     12890   H376.VI.52     4 mos      6CD66C         10209      primary somatosensory cortex (area S1, areas 3,1,2)                    S1C          EC813B                   10153                  neural plate                               NP                    D7D8D8
# 23     12890   H376.VI.52     4 mos      6CD66C         10225                posteroventral (inferior) parietal cortex                    IPC          D38E32                   10153                  neural plate                               NP                    D7D8D8
# 24     12890   H376.VI.52     4 mos      6CD66C         10236                           primary auditory cortex (core)                    A1C          D670A0                   10153                  neural plate                               NP                    D7D8D8
# 25     12890   H376.VI.52     4 mos      6CD66C         10243   posterior (caudal) superior temporal cortex (area 22c)                    STC          D670A0                   10153                  neural plate                               NP                    D7D8D8
# 26     12890   H376.VI.52     4 mos      6CD66C         10252        inferolateral temporal cortex (area TEv, area 20)                    ITC          D55C92                   10153                  neural plate                               NP                    D7D8D8
# 27     12890   H376.VI.52     4 mos      6CD66C         10269       primary visual cortex (striate cortex, area V1/17)                    V1C          C13331                   10153                  neural plate                               NP                    D7D8D8
# 28     12890   H376.VI.52     4 mos      6CD66C         10294                      hippocampus (hippocampal formation)                    HIP          BFB5D5                   10292                    allocortex                              ACx                    D1CEE2
# 29     12890   H376.VI.52     4 mos      6CD66C         10361                                       amygdaloid complex                    AMY          C9E2B1                   10153                  neural plate                               NP                    D7D8D8
# 30     12890   H376.VI.52     4 mos      6CD66C         10333                                                 striatum                    STR          C1CEA7                   10332  basal nuclei (basal ganglia)                               BN                    E2EACA
# 31     12890   H376.VI.52     4 mos      6CD66C         10398                          mediodorsal nucleus of thalamus                     MD          B067A9                   10390                      thalamus                              THM                    E4CCE3
# 32     12890   H376.VI.52     4 mos      6CD66C         10657                                        cerebellar cortex                    CBC          89ADDB                   10153                  neural plate                               NP                    D7D8D8
# 33     12977  H376.VII.51    10 mos      B0EB3B         10173                           dorsolateral prefrontal cortex                    DFC          D4B235                   10153                  neural plate                               NP                    D7D8D8
# 34     12977  H376.VII.51    10 mos      B0EB3B         10278  anterior (rostral) cingulate (medial prefrontal) cortex                    MFC          E26880                   10153                  neural plate                               NP                    D7D8D8
# 35     12977  H376.VII.51    10 mos      B0EB3B         10194                                   orbital frontal cortex                    OFC          E2D4A7                   10153                  neural plate                               NP                    D7D8D8
# 36     12977  H376.VII.51    10 mos      B0EB3B         10209      primary somatosensory cortex (area S1, areas 3,1,2)                    S1C          EC813B                   10153                  neural plate                               NP                    D7D8D8
# 37     12977  H376.VII.51    10 mos      B0EB3B         10225                posteroventral (inferior) parietal cortex                    IPC          D38E32                   10153                  neural plate                               NP                    D7D8D8
# 38     12977  H376.VII.51    10 mos      B0EB3B         10243   posterior (caudal) superior temporal cortex (area 22c)                    STC          D670A0                   10153                  neural plate                               NP                    D7D8D8
# 39     12977  H376.VII.51    10 mos      B0EB3B         10252        inferolateral temporal cortex (area TEv, area 20)                    ITC          D55C92                   10153                  neural plate                               NP                    D7D8D8
# 40     12977  H376.VII.51    10 mos      B0EB3B         10269       primary visual cortex (striate cortex, area V1/17)                    V1C          C13331                   10153                  neural plate                               NP                    D7D8D8
# 41     12977  H376.VII.51    10 mos      B0EB3B         10398                          mediodorsal nucleus of thalamus                     MD          B067A9                   10390                      thalamus                              THM                    E4CCE3
# 42     12977  H376.VII.51    10 mos      B0EB3B         10657                                        cerebellar cortex                    CBC          89ADDB                   10153                  neural plate                               NP                    D7D8D8

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'donor_age' and 'structure_name' are columns in your DataFrame

plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.scatterplot(x='donor_age', y='structure_name', data=df, hue='structure_name', palette='bright')
plt.title('Donor Age vs Structure Name')
plt.xlabel('Donor Age')
plt.ylabel('Structure Name')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.legend(title='Structure Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='donor_age', hue='structure_name', data=df)
plt.title('Donor Age vs Structure Name')
plt.xlabel('Donor Age')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Structure Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='structure_name', y='donor_age', data=df)
plt.title('Donor Age Distribution by Structure Name')
plt.xlabel('Structure Name')
plt.ylabel('Donor Age')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'structure_name' and 'donor_age' are columns in your DataFrame

# Group the data by 'structure_name' and count the occurrences of each age
structure_age_counts = df.groupby(['structure_name', 'donor_age'])['donor_age'].count().unstack()

# Create the stacked bar chart
structure_age_counts.plot(kind='bar', stacked=True, figsize=(12, 6))

plt.title('Donor Age Distribution by Structure Name (Stacked Bar Chart)')
plt.xlabel('Structure Name')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Donor Age')
plt.tight_layout()
plt.show()
