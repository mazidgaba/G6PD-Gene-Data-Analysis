# %% [markdown]
# <a href="https://colab.research.google.com/github/mazidgaba/G6PD-Gene-Data-Analysis/blob/main/21_40yrs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Assuming the file is in the same directory as your notebook
# Replace '21-40yrs.xlsx' with the actual file path if it's different
df = pd.read_excel('21-40yrs.xlsx')

# Print the first few rows to verify it's loaded correctly
print(df.head())
# Out:
#    donor_id  donor_name donor_age donor_color  structure_id  \
# 0     12365  H376.IV.51    21 pcw      00EBEB         10252
# 1     12365  H376.IV.51    21 pcw      00EBEB         10657
# 2     12886  H376.IV.54    21 pcw      00D6D6         10173
# 3     12886  H376.IV.54    21 pcw      00D6D6         10185
# 4     12886  H376.IV.54    21 pcw      00D6D6         10278
#
#                                       structure_name structure_abbreviation  \
# 0  inferolateral temporal cortex (area TEv, area 20)                    ITC
# 1                                  cerebellar cortex                    CBC
# 2                     dorsolateral prefrontal cortex                    DFC
# 3                    ventrolateral prefrontal cortex                    VFC
# 4  anterior (rostral) cingulate (medial prefronta...                    MFC
#
#   structure_color  top_level_structure_id top_level_structure_name  \
# 0          D55C92                   10153             neural plate
# ...

# %%
print(df.to_string())
# Out:
#       donor_id    donor_name donor_age donor_color  structure_id                                           structure_name structure_abbreviation structure_color  top_level_structure_id      top_level_structure_name top_level_structure_abbreviation top_level_structure_color
# 0        12365    H376.IV.51    21 pcw      00EBEB         10252        inferolateral temporal cortex (area TEv, area 20)                    ITC          D55C92                   10153                  neural plate                               NP                    D7D8D8
# 1        12365    H376.IV.51    21 pcw      00EBEB         10657                                        cerebellar cortex                    CBC          89ADDB                   10153                  neural plate                               NP                    D7D8D8
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming 'donor_age' and 'structure_name' are columns in your DataFrame

plt.figure(figsize=(12, 6))  # Adjust figure size as needed
sns.scatterplot(x='donor_age', y='structure_name', data=df, hue='structure_name', palette='bright')
plt.title('Donor Age vs Structure Name')
plt.xlabel('Donor Age')
plt.ylabel('Structure Name')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability
plt.legend(title='Structure Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming your DataFrame is named 'df' and has 'donor_age' and 'structure_name' columns

plt.figure(figsize=(12, 6))
sns.countplot(x='structure_name', hue='donor_age', data=df)
plt.title('Structure Name vs Donor Age')
plt.xlabel('Structure Name')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Donor Age', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(x='structure_name', y='donor_age', data=df)
plt.title('Donor Age Distribution by Structure Name')
plt.xlabel('Structure Name')
plt.ylabel('Donor Age')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'structure_name' and 'donor_age' are columns in your DataFrame

# Group the data by 'structure_name' and count the occurrences of each age
structure_age_counts = df.groupby(['structure_name', 'donor_age'])['donor_age'].count().unstack()

# Create the stacked bar chart
structure_age_counts.plot(kind='bar', stacked=True, figsize=(12, 6))

plt.title('Donor Age Distribution by Structure Name (Stacked Bar Chart)')
plt.xlabel('Structure Name')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Donor Age')
plt.tight_layout()
plt.show()
